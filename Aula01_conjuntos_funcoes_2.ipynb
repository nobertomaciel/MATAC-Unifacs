# %% [markdown]
# <a href="https://colab.research.google.com/github/nobertomaciel/MATAC-Unifacs/blob/main/Aula01_conjuntos_funcoes_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = {1,2,3,4}
B = {3,4,5,6}
print(A&B)
print(A|B)
print(A-B)
# Out:
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}

# %%
U = {1,2,3,4,5,6,7}
A = {2,4,6}
print(U-A)
# Out:
# {1, 3, 5, 7}

# %%
def funct(x):
  c = 2*x+3
  print("x=",x," f(x)=",c)

for x in range(0,100,1):
  funct(x)

# %%
def funct(x):
  c = 50+10*x
  print("x=",x," f(x)=",c)

for x in range(0,100,1):
  funct(x)
# Out:
# x= 0  f(x)= 50
# x= 1  f(x)= 60
# x= 2  f(x)= 70
# x= 3  f(x)= 80
# x= 4  f(x)= 90
# x= 5  f(x)= 100
# x= 6  f(x)= 110
# x= 7  f(x)= 120
# x= 8  f(x)= 130
# x= 9  f(x)= 140
# x= 10  f(x)= 150
# x= 11  f(x)= 160
# x= 12  f(x)= 170
# x= 13  f(x)= 180
# x= 14  f(x)= 190
# x= 15  f(x)= 200
# x= 16  f(x)= 210
# x= 17  f(x)= 220
# x= 18  f(x)= 230
# x= 19  f(x)= 240
# x= 20  f(x)= 250
# x= 21  f(x)= 260
# x= 22  f(x)= 270
# x= 23  f(x)= 280
# x= 24  f(x)= 290
# x= 25  f(x)= 300
# x= 26  f(x)= 310
# x= 27  f(x)= 320
# x= 28  f(x)= 330
# x= 29  f(x)= 340
# x= 30  f(x)= 350
# x= 31  f(x)= 360
# x= 32  f(x)= 370
# x= 33  f(x)= 380
# x= 34  f(x)= 390
# x= 35  f(x)= 400
# x= 36  f(x)= 410
# x= 37  f(x)= 420
# x= 38  f(x)= 430
# x= 39  f(x)= 440
# x= 40  f(x)= 450
# x= 41  f(x)= 460
# x= 42  f(x)= 470
# x= 43  f(x)= 480
# x= 44  f(x)= 490
# x= 45  f(x)= 500
# x= 46  f(x)= 510
# x= 47  f(x)= 520
# x= 48  f(x)= 530
# x= 49  f(x)= 540
# x= 50  f(x)= 550
# x= 51  f(x)= 560
# x= 52  f(x)= 570
# ...
